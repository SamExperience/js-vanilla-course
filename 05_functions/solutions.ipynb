// %% [markdown]
// # Solutions — Functions
//
// Only look here after you've actually tried the exercises in `functions.ipynb`.

// %% [markdown]
// ### LESSON 19 — Exercise

// %%
function calculateTotal(price, quantity) {
  return price * quantity;
}

const total = calculateTotal(20, 3);

console.log(total);

// %% [markdown]
// ### LESSON 19 — Mini challenge

// %%
function isAdult(age) {
  return age >= 18;
}

const adult = isAdult(25);

console.log(adult);

// %% [markdown]
// ## Appendix — another way to write the same thing
//
// These versions also work. Comparing them with the solutions above is worth a minute: same result, different style.

// %% [markdown]
// ### LESSON 19 — Exercise, alternative version

// %%
// Wrapped in a block so these names don't clash with the solution above.
{
  function calculateTotal(price,quantity){
      return price*quantity;
  }
  let total=calculateTotal(20,3);
  console.log(total);
}

// %% [markdown]
// ### LESSON 19 — Mini challenge, alternative version
//
// Note: `return age >= 18 ? true : false` works, but the comparison is already a boolean — `return age >= 18` says the same thing.

// %%
// Wrapped in a block so these names don't clash with the solution above.
{
  function isAdult(age){
      return age >= 18 ? true : false;
  }
  let adult=isAdult(25);
  console.log(adult);
}

// %% [markdown]
// ### LESSON 20 — Exercise

// %%
function makeTag(text, tag = "p") {
  return `<${tag}>${text}</${tag}>`;
}

console.log(makeTag("Hello"));
console.log(makeTag("Hello", "h1"));

function average(...numbers) {
  if (numbers.length === 0) return 0;
  let sum = 0;
  for (const n of numbers) {
    sum += n;
  }
  return sum / numbers.length;
}

console.log(average(10, 20, 30));
console.log(average());

// %% [markdown]
// ### LESSON 20 — Mini challenge

// %%
function report(title, ...scores) {
  if (scores.length === 0) return `${title}: no scores`;

  let total = 0;
  for (const score of scores) {
    total += score;
  }

  return `${title}: ${scores.length} scores, total ${total}, average ${total / scores.length}`;
}

console.log(report("Math", 7, 9, 8));
console.log(report("Math"));

// %% [markdown]
// ### LESSON 21 — Warm-up

// %%
const half = (n) => n / 2;

console.log(half(10));

function applyTo(value, fn) {
  return fn(value);
}

console.log(applyTo(10, half));
console.log(applyTo(10, (n) => n / 2));

// %% [markdown]
// ### LESSON 21 — Exercise

// %%
const square = (n) => n * n;
console.log(square(4));

function applyTwice(value, fn) {
  return fn(fn(value));
}

console.log(applyTwice(3, square));

function greeterFor(greeting) {
  return (name) => `${greeting}, ${name}`;
}

const hello = greeterFor("Hello");
const welcome = greeterFor("Welcome");

console.log(hello("Mia"));
console.log(welcome("Alex"));

// %% [markdown]
// ### LESSON 21 — Mini challenge

// %%
function makeCounter() {
  let count = 0;
  return () => {
    count += 1;
    return count;
  };
}

const next = makeCounter();
console.log(next(), next(), next());

const other = makeCounter();
console.log(other());

// The count lives in the call to makeCounter that produced the function.
// The returned function keeps that call's variables alive, so each counter
// gets its own private count.
